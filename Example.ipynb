# %% [markdown]
# # Example
#
# For this example we use the following packages:
# - `requests` (built-in)
# - `json` (built-in)
# - `pandas` (version 1.1.3)
#
# See https://github.com/kallewesterling/drag-dataset/blob/main/requirements.txt for the requirements

# %%
import requests, json
import pandas as pd

# %% [markdown]
# Use `requests` to load the data:

# %%
r = requests.get('https://github.com/kallewesterling/drag-dataset/raw/main/data/full.json')

# %% [markdown]
# Ensure that the loading went well:

# %%
if not r.status_code == 200:
    raise RuntimeError(f'Encountered wrong status code ({r.status_code}), make sure all the addresses are correct.')

# %% [markdown]
# Use `json` package to read the resulting text:

# %%
json_data = json.loads(r.text)

# %% [markdown]
# The entire dataset can then easily be loaded into a pandas DataFrame (`df`):

# %%
df = pd.DataFrame(json_data)

# %% [markdown]
# Have a look at the DataFrame by using the built-in method `.head()`:

# %%
df.head()
# Out:
#          Date Category Performer Normalized performer Performer first-name  \
# 0  1940-02-24                  —          Roni Warren                 Roni
# 1  1940-06-20                  —      Francis Renault              Francis
# 2  1932-11-02                  —      Francis Renault              Francis
# 3  1930-02-17                  —      Francis Renault              Francis
# 4  1935-01-30                  —      Francis Renault              Francis
#
#   Performer last-name           Venue   Normalized Venue              City  \
# 0              Warren  Smith's Tavern     Smith's Tavern          Troy, NY
# 1             Renault         Club 76            Club 76  Battle Creek, MI
# 2             Renault       Paramount  Paramount Theatre    Des Moines, IA
# 3             Renault     RKO Orpheum    Orpheum Theatre    Des Moines, IA
# 4             Renault           Cameo      Cameo Theatre      Hartford, CT
#
#     Normalized City  ... Comment on edge: revue Blackface Sepia  \
# 0        Albany, NY  ...
# 1  Battle Creek, MI  ...
# 2    Des Moines, IA  ...
# 3    Des Moines, IA  ...
# 4      Hartford, CT  ...
#
#   Fan dancer/Sally Rand  Exotic/erotic/oriental dancer/Gypsy  Has image  \
# 0                                                                  True
# 1                                                                  True
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
#
#   Address Vaudeville Circuit/Circus Unsure whether drag artist  Year
# 0                                                               1940
# 1                                                               1940
# 2                                                               1932
# 3                               RKO                             1930
# 4                                                               1935
#
# [5 rows x 37 columns]

# %% [markdown]
# # Pairings
#
# If you want to have a look at a particular pairing of data, here is an example.
#
# We use the pairing of normalized performer names and normalized city names below but you can look in the `/pairings/` directory for more data files.

# %% [markdown]
# Once again, we use `requests` to load the data:

# %%
r = requests.get('https://github.com/kallewesterling/drag-dataset/raw/main/data/pairings/normalized_performer-normalized_city.json')

# %% [markdown]
# We should also, like above, make sure that our loading went well:

# %%
if not r.status_code == 200:
    raise RuntimeError(f'Encountered wrong status code ({r.status_code}), make sure all the addresses are correct.')

# %% [markdown]
# Use `json` package to read the resulting text:

# %%
json_data = json.loads(r.text)

# %% [markdown]
# Now the `json_data` can be used like any dictionary.
#
# For example, we can loop through and look at the way that we have some data for different performers.

# %%
for performer, city in json_data.items():
    if not performer:
        print(f'{len(city)} cities registered with no named performers.')
        continue
    print(f'{performer} appeared in {len(city)} cities across the dataset. For instance:', '; '.join(city[:3]))
# Out:
# 62 cities registered with no named performers.
# Adrian Ames appeared in 27 cities across the dataset. For instance: Buffalo, NY; Chicago, IL; Delaware, NJ
# Adrian Norris appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Adrienne appeared in 1 cities across the dataset. For instance: New York, NY
# Agnes Roberts appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Aimee Joye appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Al Benson appeared in 1 cities across the dataset. For instance: Chicago, IL
# Al De Lage appeared in 1 cities across the dataset. For instance: Detroit, MI
# Al DeMarco appeared in 3 cities across the dataset. For instance: Miami, FL; New York, NY; Philadelphia, PA
# Al Garbell appeared in 1 cities across the dataset. For instance: Chicago, IL
# Al Lucas appeared in 1 cities across the dataset. For instance: Warren, PA
# Al Ray appeared in 2 cities across the dataset. For instance: Chicago, IL; Cincinnati, OH
# Al St. Clair appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Al Sterling appeared in 1 cities across the dataset. For instance: Cleveland, OH
# Alan Gray appeared in 0 cities across the dataset. For instance:
# Albert Henry Cook appeared in 0 cities across the dataset. For instance:
# Albert Hogue appeared in 1 cities across the dataset. For instance: Worcester, MA
# Alberta Vaughn appeared in 11 cities across the dataset. For instance: Benton Harbor, MI; Binghamton, NY; Jamestown, NY
# Alden Garrison appeared in 2 cities across the dataset. For instance: Baltimore, MD; Washington DC
# Alfred Carmen appeared in 1 cities across the dataset. For instance: Albany, NY
# Alice E. Murphy appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Alice Rydner appeared in 1 cities across the dataset. For instance: Chicago, IL
# Alice White appeared in 1 cities across the dataset. For instance: Chicago, IL
# Allan Cook appeared in 0 cities across the dataset. For instance:
# Allen Carl appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Andrew Tribble appeared in 4 cities across the dataset. For instance: Atlantic City, NJ; Baltimore, MD; Chicago, IL
# Andy Cliff appeared in 2 cities across the dataset. For instance: Atlantic City, NJ; New York, NY
# Anita James appeared in 1 cities across the dataset. For instance: Detroit, MI
# Anthony DiMeo appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Arica Wild appeared in 4 cities across the dataset. For instance: Albany, NY; Atlantic City, NJ; New York, NY
# Art Bernard appeared in 1 cities across the dataset. For instance: Akron, OH
# Art West appeared in 5 cities across the dataset. For instance: Chicago, IL; Cleveland, OH; Kansas City, MO
# Arthur Budd appeared in 2 cities across the dataset. For instance: Miami, FL; New York, NY
# Arthur G. West appeared in 10 cities across the dataset. For instance: Binghamton, NY; Chicago, IL; Des Moines, IA
# Arthur La Delle appeared in 2 cities across the dataset. For instance: Reno, NV; Salem, OR
# Arthur Verity appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Arthur Wilson appeared in 0 cities across the dataset. For instance:
# Arvin Giese appeared in 0 cities across the dataset. For instance:
# Au Sing appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Newport, KY
# Audri Ann appeared in 1 cities across the dataset. For instance: Detroit, MI
# Bab Garrison appeared in 2 cities across the dataset. For instance: Baltimore, MD; Washington DC
# Babe Allen appeared in 4 cities across the dataset. For instance: Baltimore, MD; Chicago, IL; Kansas City, MO
# Babe Baker appeared in 3 cities across the dataset. For instance: Miami, FL; New Castle, PA; New York, NY
# Babe Gordon appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Baby Jan Ray appeared in 1 cities across the dataset. For instance: Lima, OH
# Baby Scruggs appeared in 1 cities across the dataset. For instance: Chicago, IL
# Barbette appeared in 2 cities across the dataset. For instance: Kursaal, Switzerland; New York, NY
# Beale St. Boys appeared in 1 cities across the dataset. For instance: New York, NY
# Beatrice Howle appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bee Lockhart appeared in 1 cities across the dataset. For instance: New York, NY
# Bel Ager appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Benny Pauly appeared in 2 cities across the dataset. For instance: Bloomington, IL; Cincinnati, OH
# Bernice Hollenbeck appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Bernie Salin appeared in 1 cities across the dataset. For instance: Idaho Falls, ID
# Bert Errol appeared in 3 cities across the dataset. For instance: Buffalo, NY; Chicago, IL; New York, NY
# Bert Kelley appeared in 1 cities across the dataset. For instance: New York, NY
# Bert Savoy appeared in 0 cities across the dataset. For instance:
# Bert Sherry appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Bert Wheeler appeared in 2 cities across the dataset. For instance: New York, NY; Seattle, WA
# Bertie Bierman appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Bessie Brennan appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Bette Newmon appeared in 2 cities across the dataset. For instance: Miami, FL; New York, NY
# Betty Borgreve appeared in 1 cities across the dataset. For instance: New York, NY
# Betty Colton appeared in 1 cities across the dataset. For instance: New York, NY
# Betty Juhlien appeared in 1 cities across the dataset. For instance: Seattle, WA
# Betty Lee appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Betty Munden appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Beulah Kennedy appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Bill Howard appeared in 1 cities across the dataset. For instance: Miami, FL
# Bill Jones appeared in 0 cities across the dataset. For instance:
# Bill Kennedy appeared in 1 cities across the dataset. For instance: Miami, FL
# Bill Nealy appeared in 1 cities across the dataset. For instance: Asbury Park, NJ
# Billie Berke appeared in 1 cities across the dataset. For instance: Akron, OH
# Billie Beryl appeared in 7 cities across the dataset. For instance: Bakersfield, CA; Baltimore, MD; Cincinnati, OH
# Billie Brannon appeared in 9 cities across the dataset. For instance: Asbury Park, NJ; Baltimore, MD; Buffalo, NY
# Billie Dale appeared in 1 cities across the dataset. For instance: Rock Island, IL
# Billie Davis appeared in 2 cities across the dataset. For instance: Atlantic City, NJ; New York, NY
# Billie Dove appeared in 1 cities across the dataset. For instance: Washington DC
# Billie Gilbert appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Billie Kemp appeared in 1 cities across the dataset. For instance: Newport, KY
# Billie Marsh appeared in 0 cities across the dataset. For instance:
# Billie McAllister appeared in 2 cities across the dataset. For instance: Chicago, IL; Washington DC
# Billie Richmond appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Billie Russell appeared in 3 cities across the dataset. For instance: Chicago, IL; Kansas City, MO; Miami, FL
# Billie Sinclair appeared in 1 cities across the dataset. For instance: Chicago, IL
# Billy appeared in 1 cities across the dataset. For instance: New York, NY
# Billy "Senorita" Herrera appeared in 20 cities across the dataset. For instance: Atlanta, GA; Baltimore, MD; Chicago, IL
# Billy Ardelle appeared in 0 cities across the dataset. For instance:
# Billy Brill appeared in 5 cities across the dataset. For instance: Atlantic City, NJ; Baltimore, MD; Detroit, MI
# Billy Byrne appeared in 0 cities across the dataset. For instance:
# Billy Daye appeared in 1 cities across the dataset. For instance: New York, NY
# Billy Earle appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Billy Hayes appeared in 8 cities across the dataset. For instance: Benton Harbor, MI; Detroit, MI; Lexington, KY
# Billy Irwin appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Zanesville, OH
# Billy Joy appeared in 2 cities across the dataset. For instance: Detroit, MI; New York, NY
# Billy Kamp appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Billy Kent appeared in 1 cities across the dataset. For instance: Akron, OH
# Billy Lamont appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Detroit, MI
# Billy Lynn appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Billy Monti appeared in 1 cities across the dataset. For instance: Miami, FL
# Billy Nichols appeared in 0 cities across the dataset. For instance:
# Billy O'Brien appeared in 2 cities across the dataset. For instance: New York, NY; Syracuse, NY
# Billy Pinnell appeared in 1 cities across the dataset. For instance: Columbus, OH
# Billy Reed appeared in 1 cities across the dataset. For instance: New York, NY
# Billy Richards appeared in 9 cities across the dataset. For instance: Chicago, IL; Cincinnati, OH; Echo, LA
# Billy Rohmer appeared in 9 cities across the dataset. For instance: Chicago, IL; Cleveland, OH; Detroit, MI
# Billy Rosser appeared in 1 cities across the dataset. For instance: Miami, FL
# Billy Turner appeared in 1 cities across the dataset. For instance: Warren, PA
# Billy West appeared in 6 cities across the dataset. For instance: Albany, NY; Baltimore, MD; Delaware, NJ
# Blackie Dennis appeared in 2 cities across the dataset. For instance: Miami, FL; New York, NY
# Bob Lake appeared in 1 cities across the dataset. For instance: New York, NY
# Bob Mack appeared in 1 cities across the dataset. For instance: Reno, NV
# Bob Smith appeared in 3 cities across the dataset. For instance: Boston, MA; New York, NY; Portland, ME
# Bobbie Baker appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Bobbie Bell appeared in 9 cities across the dataset. For instance: Akron, OH; Chicago, IL; Cincinnati, OH
# Bobbie Blue appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Bobbie Chapman appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bobbie Clark appeared in 3 cities across the dataset. For instance: New York, NY; Pittsburgh, PA; Portland, ME
# Bobbie Davis appeared in 2 cities across the dataset. For instance: Chicago, IL; New York, NY
# Bobbie Grant appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bobbie Kaye appeared in 2 cities across the dataset. For instance: Detroit, MI; Kansas City, MO
# Bobbie La Marr appeared in 14 cities across the dataset. For instance: Albany, NY; Buffalo, NY; Chicago, IL
# Bobbie Macklin appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bobbie Marlowe appeared in 2 cities across the dataset. For instance: Pittsburgh, PA; Warren, PA
# Bobbie Ray appeared in 3 cities across the dataset. For instance: New York, NY; Portland, ME; Sacramento, CA
# Bobbie Rowland appeared in 1 cities across the dataset. For instance: New York, NY
# Bobby Allen appeared in 9 cities across the dataset. For instance: Benton Harbor, MI; Cincinnati, OH; Dayton, OH
# Bobby Anderson appeared in 2 cities across the dataset. For instance: Los Angeles, CA; Miami, FL
# Bobby Bell appeared in 3 cities across the dataset. For instance: Kansas City, MO; New Orleans, LA; San Antonio, TX
# Bobby Brennan appeared in 7 cities across the dataset. For instance: Akron, OH; Albany, NY; Cincinnati, OH
# Bobby Brown appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Bobby Cummins appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Bobby D'Castro appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Bobby Dean appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Bobby Dell appeared in 4 cities across the dataset. For instance: Detroit, MI; New York, NY; Philadelphia, PA
# Bobby Ferguson appeared in 2 cities across the dataset. For instance: Detroit, MI; Washington DC
# Bobby Gay appeared in 1 cities across the dataset. For instance: Hartford, CT
# Bobby Gordon appeared in 3 cities across the dataset. For instance: Los Angeles, CA; San Antonio, TX; San Francisco, CA
# Bobby Grant appeared in 3 cities across the dataset. For instance: Chicago, IL; Kansas City, MO; Nashville, TN
# Bobby Hayes appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Bobby Johnson appeared in 6 cities across the dataset. For instance: Asbury Park, NJ; Cleveland, OH; Detroit, MI
# Bobby Jones appeared in 3 cities across the dataset. For instance: Lansing, MI; New York, NY; Philadelphia, PA
# Bobby Kork appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Bobby La Rue appeared in 9 cities across the dataset. For instance: Columbus, OH; Detroit, MI; East Liverpool, OH
# Bobby Lane appeared in 1 cities across the dataset. For instance: East Liverpool, OH
# Bobby Leonard appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Bobby Mason appeared in 1 cities across the dataset. For instance: Boston, MA
# Bobby McNeer appeared in 1 cities across the dataset. For instance: New York, NY
# Bobby Mitchell appeared in 1 cities across the dataset. For instance: Shamokin, PA
# Bobby Morris appeared in 0 cities across the dataset. For instance:
# Bobby Norman appeared in 6 cities across the dataset. For instance: Binghamton, NY; Jamestown, NY; New York, NY
# Bobby Roberts appeared in 1 cities across the dataset. For instance: Salinas, CA
# Bobby Royce appeared in 0 cities across the dataset. For instance:
# Bobby Stevens appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bobby Sullivan appeared in 2 cities across the dataset. For instance: Albany, NY; Saratoga Springs, NY
# Bobby Trent appeared in 2 cities across the dataset. For instance: Hazleton, PA; Miami, FL
# Bobby Verrill appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Bobby Young appeared in 1 cities across the dataset. For instance: Salinas, CA
# Bohannan appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bonnie appeared in 1 cities across the dataset. For instance: New York, NY
# Bonnie Clark appeared in 1 cities across the dataset. For instance: New York, NY
# Bonnie Lee appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Boots Lavana appeared in 4 cities across the dataset. For instance: Baltimore, MD; Buffalo, NY; Cleveland, OH
# Bothwell Browne appeared in 2 cities across the dataset. For instance: Indianapolis, IN; San Francisco, CA
# Brannan Fernandez appeared in 0 cities across the dataset. For instance:
# Brooks Twins appeared in 2 cities across the dataset. For instance: Baltimore, MD; Detroit, MI
# Bucky Buckworth appeared in 1 cities across the dataset. For instance: Freeport, NY
# Bud Byron appeared in 1 cities across the dataset. For instance: Chicago, IL
# Bud Hart appeared in 1 cities across the dataset. For instance: Benton Harbor, MI
# Buddy Mayo appeared in 4 cities across the dataset. For instance: Amory, MS; Benton Harbor, MI; Cincinnati, OH
# Buddy Rokahr appeared in 1 cities across the dataset. For instance: El Paso, TX
# Bunny appeared in 1 cities across the dataset. For instance: New York, NY
# Bunny Bates appeared in 1 cities across the dataset. For instance: New York, NY
# Bunny Daye appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Bunny Dorne appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Bunny Thomas appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Buster Brant appeared in 1 cities across the dataset. For instance: Zanesville, OH
# Buster Hewitt appeared in 1 cities across the dataset. For instance: East Liverpool, OH
# Candace appeared in 1 cities across the dataset. For instance: Flagstaff, AZ
# Candy Cain appeared in 0 cities across the dataset. For instance:
# Cardie Woodie appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Carey Davis appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Carl Clewis appeared in 2 cities across the dataset. For instance: Atlantic City, NJ; Los Angeles, CA
# Carl Nixon appeared in 1 cities across the dataset. For instance: New York, NY
# Carll Morgan appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Carlo Levins appeared in 4 cities across the dataset. For instance: Benton Harbor, MI; Lansing, MI; Lexington, KY
# Carlos J. Henderson appeared in 1 cities across the dataset. For instance: New York, NY
# Carmen Del Carmen appeared in 1 cities across the dataset. For instance: Council Bluffs, IA
# Carmencita appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Carol Lee appeared in 1 cities across the dataset. For instance: Chicago, IL
# Carol Mack appeared in 2 cities across the dataset. For instance: Kansas City, MO; New York, NY
# Carole Le Claire appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Carrol Thomas appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Carroll appeared in 1 cities across the dataset. For instance: Fairbanks, AK
# Carroll Davis appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Carroll Wallace appeared in 2 cities across the dataset. For instance: Sacramento, CA; San Francisco, CA
# Cary Davis appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Cecil Mason appeared in 1 cities across the dataset. For instance: New York, NY
# Ceylon appeared in 1 cities across the dataset. For instance: New York, NY
# Champagne appeared in 2 cities across the dataset. For instance: Boston, MA; Downington, PA
# Charles Alexander appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Charles Ander appeared in 1 cities across the dataset. For instance: Washington DC
# Charles Bell appeared in 1 cities across the dataset. For instance: Columbus, OH
# Charles Busch appeared in 1 cities across the dataset. For instance: New York, NY
# Charles Davis appeared in 1 cities across the dataset. For instance: Washington DC
# Charles Hooven appeared in 1 cities across the dataset. For instance: New York, NY
# Charles Moore appeared in 1 cities across the dataset. For instance: Buena Vista Springs, PA
# Charles Pierce appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Charles Wilhelm appeared in 1 cities across the dataset. For instance: Indianapolis, IN
# Charley Anderson appeared in 1 cities across the dataset. For instance: Chicago, IL
# Charley Brugnone appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Charlie Neid appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Cherie O'Dea appeared in 1 cities across the dataset. For instance: Miami, FL
# Chick Chandler appeared in 0 cities across the dataset. For instance:
# Chicki Forrest appeared in 1 cities across the dataset. For instance: San Antonio, TX
# Chickie Charms appeared in 2 cities across the dataset. For instance: Benton Harbor, MI; Chicago, IL
# Chickie Mears appeared in 4 cities across the dataset. For instance: East Liverpool, OH; Lexington, KY; Los Angeles, CA
# Chris Ames appeared in 1 cities across the dataset. For instance: New York, NY
# Chris Bailey appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Christopher Bridgeman appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Chubby Smith appeared in 1 cities across the dataset. For instance: Poughkeepsie, NY
# Chuck Marvin appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Chunga Ochoa appeared in 1 cities across the dataset. For instance: New York, NY
# Clair Carlisle appeared in 1 cities across the dataset. For instance: Minneapolis, MN
# Claire Ray appeared in 1 cities across the dataset. For instance: New York, NY
# Clara Bow appeared in 2 cities across the dataset. For instance: Baltimore, MD; Pittsburgh, PA
# Clare St. Clair appeared in 1 cities across the dataset. For instance: Lansing, MI
# Clarence Long appeared in 0 cities across the dataset. For instance:
# Clarence Spicer appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Clarence Thomas appeared in 0 cities across the dataset. For instance:
# Clarence Weems appeared in 1 cities across the dataset. For instance: Chicago, IL
# Clarenz Henderson appeared in 1 cities across the dataset. For instance: New York, NY
# Claudetener appeared in 1 cities across the dataset. For instance: Chicago, IL
# Cleo Renee appeared in 3 cities across the dataset. For instance: Detroit, MI; Minneapolis, MN; Pensacola, FL
# Cleo Stafford appeared in 1 cities across the dataset. For instance: Sacramento, CA
# Cliff LaVerne appeared in 1 cities across the dataset. For instance: Welch, WV
# Clifford Bell appeared in 1 cities across the dataset. For instance: Chicago, IL
# Cliftonn Argue appeared in 2 cities across the dataset. For instance: New York, NY; Warren, PA
# Clinton De Forrest appeared in 1 cities across the dataset. For instance: New York, NY
# Connie appeared in 1 cities across the dataset. For instance: Hazleton, PA
# Connie Miller appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Connie Walsh appeared in 8 cities across the dataset. For instance: Benton Harbor, MI; Binghamton, NY; Detroit, MI
# Conrad Fitzgerald appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Constance Bennett appeared in 1 cities across the dataset. For instance: Chicago, IL
# Craig Russell appeared in 1 cities across the dataset. For instance: New York, NY
# Crystal Lane appeared in 1 cities across the dataset. For instance: Downington, PA
# Daisey Dee appeared in 1 cities across the dataset. For instance: New York, NY
# Daisy Devoe appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Daisy Navarro appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Dale Roberts appeared in 1 cities across the dataset. For instance: New York, NY
# Dan Carson appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Danny Brown appeared in 10 cities across the dataset. For instance: Akron, OH; Albany, NY; Asbury Park, NJ
# Danny King appeared in 4 cities across the dataset. For instance: Benton Harbor, MI; Cincinnati, OH; Lansing, MI
# Danny Lee appeared in 1 cities across the dataset. For instance: Echo, LA
# Darryl? Gilbert? appeared in 2 cities across the dataset. For instance: Denver, CO; Rock Island, IL
# Dave Davis appeared in 1 cities across the dataset. For instance: Montgomery, AL
# Dave Gold appeared in 1 cities across the dataset. For instance: Miami, FL
# Dave Rafael appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Dave Shaw appeared in 3 cities across the dataset. For instance: Albany, NY; Miami, FL; Saratoga Springs, NY
# David J. Doyle appeared in 1 cities across the dataset. For instance: New York, NY
# Davy Lee appeared in 1 cities across the dataset. For instance: Lansing, MI
# Dawn Sis appeared in 1 cities across the dataset. For instance: Chicago, IL
# Day Sherry appeared in 2 cities across the dataset. For instance: New York, NY; Portland, ME
# Deanna Durbin appeared in 1 cities across the dataset. For instance: Centralia, IL
# Dee Liddell appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Del Dreer appeared in 1 cities across the dataset. For instance: Albany, NY
# Del Le Roy appeared in 9 cities across the dataset. For instance: Albany, NY; Australia; Cleveland, OH
# Del Raye appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Cleveland, OH
# Dell Day appeared in 13 cities across the dataset. For instance: Bakersfield, CA; Emporia, KS; Fort Collins, CO
# Delores Del Rio appeared in 1 cities across the dataset. For instance: Centralia, IL
# Delorice De'Fren appeared in 0 cities across the dataset. For instance:
# Dennis Griffin appeared in 1 cities across the dataset. For instance: Albany, NY
# Dick Buckley appeared in 1 cities across the dataset. For instance: Miami, FL
# Dick Hastings appeared in 0 cities across the dataset. For instance:
# Dick Lane appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Dick Ricardo appeared in 2 cities across the dataset. For instance: New York, NY; Portland, ME
# Dickie Ray appeared in 2 cities across the dataset. For instance: Jamestown, NY; Warren, PA
# Dimples appeared in 1 cities across the dataset. For instance: Paterson, NJ
# Dixie Day appeared in 1 cities across the dataset. For instance: Boston, MA
# Dixie DeLane appeared in 5 cities across the dataset. For instance: Atlantic City, NJ; Philadelphia, PA; Pottstown, PA
# Dixie Dixon appeared in 6 cities across the dataset. For instance: Columbus, OH; Dayton, OH; Detroit, MI
# Dixie Jean appeared in 1 cities across the dataset. For instance: Chicago, IL
# Dixie Lee appeared in 4 cities across the dataset. For instance: Baltimore, MD; Chicago, IL; Pittsburgh, PA
# Dodi Daniels appeared in 1 cities across the dataset. For instance: New York, NY
# Dolly Levins appeared in 1 cities across the dataset. For instance: Lansing, MI
# Dolly O'Day appeared in 1 cities across the dataset. For instance: Benton Harbor, MI
# Dom Tangee appeared in 1 cities across the dataset. For instance: Boston, MA
# Don Holly appeared in 2 cities across the dataset. For instance: Baltimore, MD; Cincinnati, OH
# Don Kenyard appeared in 2 cities across the dataset. For instance: Bakersfield, CA; San Francisco, CA
# Don La Rue appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Don Niles appeared in 2 cities across the dataset. For instance: Baltimore, MD; San Francisco, CA
# Don Rand appeared in 8 cities across the dataset. For instance: Baltimore, MD; Buffalo, NY; Detroit, MI
# Donald Grey appeared in 3 cities across the dataset. For instance: Kansas City, MO; Los Angeles, CA; Miami, FL
# Donna Glover appeared in 1 cities across the dataset. For instance: Lima, OH
# Donnie Dawn appeared in 3 cities across the dataset. For instance: New Orleans, LA; Pittsburgh, PA; Syracuse, NY
# Dora Jar appeared in 1 cities across the dataset. For instance: Downington, PA
# Doris appeared in 1 cities across the dataset. For instance: Chicago, IL
# Doris (Dimples) White appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Doris Lorraine appeared in 0 cities across the dataset. For instance:
# Doris White appeared in 1 cities across the dataset. For instance: Chicago, IL
# Dorothy Page appeared in 1 cities across the dataset. For instance: Youngstown, OH
# Dottie Johns appeared in 1 cities across the dataset. For instance: Miami, FL
# Douglas Byng appeared in 1 cities across the dataset. For instance: New York, NY
# Doyle Mack appeared in 6 cities across the dataset. For instance: Benton Harbor, MI; Chicago, IL; Kansas City, MO
# E. Russell appeared in 3 cities across the dataset. For instance: Albany, NY; New York, NY; Piscataway, NJ
# E. Walter appeared in 1 cities across the dataset. For instance: Birmingham, AL
# Earl Partello appeared in 1 cities across the dataset. For instance: Chicago, IL
# Ed-Na Link appeared in 2 cities across the dataset. For instance: Hazleton, PA; New York, NY
# Eddie Adams appeared in 1 cities across the dataset. For instance: New York, NY
# Eddie Crawford appeared in 2 cities across the dataset. For instance: Syracuse, NY; Wappingers Falls, NY
# Eddie Cushenberry appeared in 1 cities across the dataset. For instance: Lawnside, NJ
# Eddie Doyle appeared in 1 cities across the dataset. For instance: Massillon, OH
# Eddie Green appeared in 2 cities across the dataset. For instance: Freeport, NY; New York, NY
# Eddie Guertin appeared in 1 cities across the dataset. For instance: New York, NY
# Eddie La Rue appeared in 1 cities across the dataset. For instance: Seattle, WA
# Eddie Lee appeared in 3 cities across the dataset. For instance: Los Angeles, CA; Meadville, PA; San Francisco, CA
# Eddie Morton appeared in 7 cities across the dataset. For instance: Chicago, IL; Cleveland, OH; Detroit, MI
# Eddie Rogers appeared in 1 cities across the dataset. For instance: New York, NY
# Eddie White appeared in 1 cities across the dataset. For instance: Chicago, IL
# Edith Anderson appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Edmund Link appeared in 2 cities across the dataset. For instance: Baltimore, MD; Syracuse, NY
# Edna Leonard appeared in 1 cities across the dataset. For instance: Chicago, IL
# Edward Albert Crawford appeared in 1 cities across the dataset. For instance: Wappingers Falls, NY
# Edward Allworth appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Edward Collins appeared in 1 cities across the dataset. For instance: Cleveland, OH
# Edward Delange appeared in 1 cities across the dataset. For instance: Chicago, IL
# Edward F. Dolan appeared in 1 cities across the dataset. For instance: New York, NY
# Edward Lerner appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Edythe Bantos appeared in 1 cities across the dataset. For instance: Akron, OH
# El-Kay appeared in 1 cities across the dataset. For instance: Chicago, IL
# Eli Madlof appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Elsie Day appeared in 0 cities across the dataset. For instance:
# Elsie the Cobra Woman appeared in 0 cities across the dataset. For instance:
# Elton Paris appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Enna Davison appeared in 2 cities across the dataset. For instance: Chicago, IL; Miami, FL
# Ernest Davidson appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Estelle Thomas appeared in 1 cities across the dataset. For instance: New York, NY
# Etailook Hoy appeared in 0 cities across the dataset. For instance:
# Eugene Ebol appeared in 1 cities across the dataset. For instance: New York, NY
# Eva Marie Saint appeared in 1 cities across the dataset. For instance: Chicago, IL
# Eve Lynn appeared in 1 cities across the dataset. For instance: Miami, FL
# Evelyn West appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Oakland, CA
# Farfariello appeared in 1 cities across the dataset. For instance: New York, NY
# Fay Elliot appeared in 1 cities across the dataset. For instance: New York, NY
# Fay Norman appeared in 15 cities across the dataset. For instance: Benton Harbor, MI; Buffalo, NY; Cincinnati, OH
# Ferne Proctor appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Fifi appeared in 1 cities across the dataset. For instance: Harrisburg, PA
# Fifi Darling appeared in 1 cities across the dataset. For instance: Miami, FL
# Flo Arden appeared in 1 cities across the dataset. For instance: Sandusky, OH
# Floradora Sextette appeared in 1 cities across the dataset. For instance: Warren, PA
# Florence King appeared in 2 cities across the dataset. For instance: East Liverpool, OH; Los Angeles, CA
# Florence Marcus appeared in 1 cities across the dataset. For instance: Seattle, WA
# Florence Sanger appeared in 1 cities across the dataset. For instance: New York, NY
# Floyd Savage appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Frances appeared in 1 cities across the dataset. For instance: Miami, FL
# Frances David appeared in 5 cities across the dataset. For instance: Chicago, IL; Detroit, MI; Kansas City, MO
# Frances Dee appeared in 1 cities across the dataset. For instance: Chicago, IL
# Frances Dunn appeared in 2 cities across the dataset. For instance: Miami, FL; New York, NY
# Frances Fay appeared in 1 cities across the dataset. For instance: New York, NY
# Frances Hall appeared in 1 cities across the dataset. For instance: Miami, FL
# Frances La Verne appeared in 5 cities across the dataset. For instance: Bakersfield, CA; Kansas City, MO; New York, NY
# Frances Lee appeared in 4 cities across the dataset. For instance: Albany, NY; Cincinnati, OH; Detroit, MI
# Francis Blair appeared in 11 cities across the dataset. For instance: Chico, CA; Colorado Springs, CO; Kansas City, MO
# Francis Bond appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Francis Bouche appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Francis Davis appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Francis Logan appeared in 0 cities across the dataset. For instance:
# Francis Loite appeared in 0 cities across the dataset. For instance:
# Francis Lucas appeared in 1 cities across the dataset. For instance: Miami, FL
# Francis Parker appeared in 1 cities across the dataset. For instance: New York, NY
# Francis Renault appeared in 80 cities across the dataset. For instance: Aiken, SC; Akron, OH; Albuquerque, NM
# Francis Ritz appeared in 2 cities across the dataset. For instance: Cincinnati, OH; Newport, KY
# Francis Russell appeared in 5 cities across the dataset. For instance: Atlanta, GA; Echo, LA; Miami, FL
# Francis Stillman appeared in 6 cities across the dataset. For instance: Baltimore, MD; Cincinnati, OH; Detroit, MI
# Francis Strom appeared in 2 cities across the dataset. For instance: Akron, OH; Massillon, OH
# Francois Densmore appeared in 1 cities across the dataset. For instance: New York, NY
# Frank Barrett Carman appeared in 0 cities across the dataset. For instance:
# Frank Burns appeared in 0 cities across the dataset. For instance:
# Frank Doran appeared in 12 cities across the dataset. For instance: Binghamton, NY; Chicago, IL; Des Moines, IA
# Frank E. Carroll appeared in 1 cities across the dataset. For instance: New York, NY
# Frank Gaines appeared in 1 cities across the dataset. For instance: Miami, FL
# Frank Keith appeared in 1 cities across the dataset. For instance: Baltimore, MD
# Frank Perry appeared in 2 cities across the dataset. For instance: Olean, NY; Warren, PA
# Frank Quinn appeared in 2 cities across the dataset. For instance: Miami, FL; Pottstown, PA
# Frank Tymm appeared in 1 cities across the dataset. For instance: Chicago, IL
# Frankie appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Frankie Davis appeared in 1 cities across the dataset. For instance: Pottstown, PA
# Frankie Gondone appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Frankie Huntsinger appeared in 1 cities across the dataset. For instance: Casper, WY
# Frankie Quinn appeared in 1 cities across the dataset. For instance: New York, NY
# Frankie Stroud appeared in 6 cities across the dataset. For instance: Benton Harbor, MI; Chicago, IL; Kansas City, MO
# Fred Berrens appeared in 0 cities across the dataset. For instance:
# Fred Moore appeared in 1 cities across the dataset. For instance: New York, NY
# Fred Munroe appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Fred Noll appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Fred Van/Freda Van appeared in 1 cities across the dataset. For instance: Chicago, IL
# Freddie Barlow appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Freddie Monroe appeared in 1 cities across the dataset. For instance: New York, NY
# Freddie Phillips appeared in 2 cities across the dataset. For instance: Baltimore, MD; Philadelphia, PA
# Freddie Renault appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Freddie Wheeler appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Freddy Wheeler appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Fredricka appeared in 1 cities across the dataset. For instance: New York, NY
# Fritz Cantz appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Fritzie Feltz appeared in 1 cities across the dataset. For instance: Miami, FL
# Funny Fanny appeared in 7 cities across the dataset. For instance: Benton Harbor, MI; Dayton, OH; La Crosse, WI
# G. Doran appeared in 10 cities across the dataset. For instance: Binghamton, NY; Chicago, IL; Des Moines, IA
# G. G. Allen appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Gabby Lee appeared in 1 cities across the dataset. For instance: Miami, FL
# Gale Page appeared in 1 cities across the dataset. For instance: Chicago, IL
# Garbo appeared in 1 cities across the dataset. For instance: Benton Harbor, MI
# Garry Teasdale appeared in 3 cities across the dataset. For instance: Albany, NY; Baltimore, MD; Buffalo, NY
# Gary Edwards appeared in 1 cities across the dataset. For instance: Uniontown, PA
# Gay Byerd appeared in 1 cities across the dataset. For instance: Lansing, MI
# Geane Ray appeared in 1 cities across the dataset. For instance: New York, NY
# Gene Abbott appeared in 1 cities across the dataset. For instance: Echo, LA
# Gene Baye appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Gene Casali appeared in 5 cities across the dataset. For instance: Atlantic City, NJ; Nassau, NY; New York, NY
# Gene Dana appeared in 13 cities across the dataset. For instance: Chicago, IL; Cleveland, OH; Detroit, MI
# Gene Darling appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Gene Ford appeared in 3 cities across the dataset. For instance: Cicero, IL; Columbus, OH; St. Louis, MO
# Gene Gordon appeared in 3 cities across the dataset. For instance: Chicago, IL; Kansas City, MO; New Orleans, LA
# Gene Jeanette appeared in 1 cities across the dataset. For instance: Chicago, IL
# Gene Kauffyn appeared in 1 cities across the dataset. For instance: Chicago, IL
# Gene Lewis appeared in 1 cities across the dataset. For instance: New York, NY
# Gene Mason appeared in 1 cities across the dataset. For instance: Detroit, MI
# Gene Mosely appeared in 0 cities across the dataset. For instance:
# Gene Pearson appeared in 2 cities across the dataset. For instance: Cleveland, OH; New York, NY
# Gene Renee appeared in 5 cities across the dataset. For instance: Hartford, CT; Kansas City, MO; Los Angeles, CA
# Gene Russell appeared in 1 cities across the dataset. For instance: Miami, FL
# George Charles appeared in 0 cities across the dataset. For instance:
# George Daniels appeared in 1 cities across the dataset. For instance: Asbury Park, NJ
# George Denny appeared in 1 cities across the dataset. For instance: New York, NY
# George Hayes appeared in 3 cities across the dataset. For instance: Akron, OH; Massillon, OH; Sandusky, OH
# George Kelly appeared in 3 cities across the dataset. For instance: Albany, NY; Miami, FL; Saratoga Springs, NY
# George Levin appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# George Mason appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# George McDowell appeared in 2 cities across the dataset. For instance: Chicago, IL; Cincinnati, OH
# George Oliver appeared in 1 cities across the dataset. For instance: Chicago, IL
# George Page appeared in 1 cities across the dataset. For instance: Detroit, MI
# George Parker appeared in 1 cities across the dataset. For instance: New York, NY
# George Spelikos appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Georgie Burns appeared in 1 cities across the dataset. For instance: New York, NY
# Georgie Kaye appeared in 5 cities across the dataset. For instance: Cleveland, OH; Miami, FL; New Orleans, LA
# Gerry Carroll appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Giggles Craig appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Gilda Gray appeared in 1 cities across the dataset. For instance: Centralia, IL
# Gina Seyllor appeared in 1 cities across the dataset. For instance: Seattle, WA
# Ginger appeared in 1 cities across the dataset. For instance: Chicago, IL
# Ginger Dunn appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Ginger Rudell appeared in 1 cities across the dataset. For instance: Miami, FL
# Gita Gilmore appeared in 9 cities across the dataset. For instance: Akron, OH; Cincinnati, OH; Corpus Christi, TX
# Gloria Armour appeared in 0 cities across the dataset. For instance:
# Gloria Jean appeared in 1 cities across the dataset. For instance: Lima, OH
# Gloria Stoddard appeared in 1 cities across the dataset. For instance: Miami, FL
# Gorda Davies appeared in 1 cities across the dataset. For instance: Albany, NY
# Gordon Lohman appeared in 0 cities across the dataset. For instance:
# Gordon Stafford appeared in 2 cities across the dataset. For instance: Detroit, MI; Houston, TX
# Grace Barrie appeared in 1 cities across the dataset. For instance: Miami, FL
# Greta Gardner appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Guilda appeared in 3 cities across the dataset. For instance: Las Vegas, NV; Miami, FL; St. Louis, MO
# Gus Dreyfus appeared in 1 cities across the dataset. For instance: New York, NY
# Gypsy Dolan appeared in 3 cities across the dataset. For instance: Casper, WY; Chicago, IL; Kansas City, MO
# Half-Pint Jaxon appeared in 1 cities across the dataset. For instance: Chicago, IL
# Harild Ishem appeared in 1 cities across the dataset. For instance: Milwaukee, WI
# Harold Hesse appeared in 0 cities across the dataset. For instance:
# Harold L. Brow appeared in 1 cities across the dataset. For instance: Detroit, MI
# Harold Ruwin appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# Harri Henri appeared in 0 cities across the dataset. For instance:
# Harry Bernie appeared in 1 cities across the dataset. For instance: New York, NY
# Harry Brown appeared in 1 cities across the dataset. For instance: New York, NY
# Harry Davis appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Harry Dowling appeared in 1 cities across the dataset. For instance: Chicago, IL
# Harry E. Brewster appeared in 1 cities across the dataset. For instance: Kansas City, MO
# Harry Fink appeared in 2 cities across the dataset. For instance: Cincinnati, OH; St. Louis, MO
# Harry Kelly appeared in 1 cities across the dataset. For instance: Miami, FL
# Harry McGhee appeared in 1 cities across the dataset. For instance: Puyallup, WA
# Harry Mick appeared in 0 cities across the dataset. For instance:
# Harry Pepper appeared in 1 cities across the dataset. For instance: New York, NY
# Harry Watson, Jr. appeared in 0 cities across the dataset. For instance:
# Harvey Lee appeared in 15 cities across the dataset. For instance: Albany, NY; Cleveland, OH; Las Vegas, NV
# Hedy Jo Star appeared in 1 cities across the dataset. For instance: New York, NY
# Helen Humes appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Helen Lee appeared in 1 cities across the dataset. For instance: New York, NY
# Helen Mack appeared in 1 cities across the dataset. For instance: Akron, OH
# Helen Tustin appeared in 2 cities across the dataset. For instance: Akron, OH; Massillon, OH
# Hemsley Winfield appeared in 1 cities across the dataset. For instance: New York, NY
# Henri Borrell appeared in 1 cities across the dataset. For instance: Atlantic City, NJ
# Henri St. Charles appeared in 1 cities across the dataset. For instance: New York, NY
# Herbert Clifton appeared in 2 cities across the dataset. For instance: New York, NY; Philadelphia, PA
# Herbert Faye appeared in 2 cities across the dataset. For instance: Binghamton, NY; New York, NY
# Herman Ferdinand appeared in 1 cities across the dataset. For instance: Chicago, IL
# Herslean Roberts appeared in 1 cities across the dataset. For instance: Chicago, IL
# Hot-Cha Hinton appeared in 4 cities across the dataset. For instance: Baltimore, MD; Cicero, IL; Colorado Springs, CO
# Howard Blair appeared in 0 cities across the dataset. For instance:
# Howard Parsons appeared in 1 cities across the dataset. For instance: Hartford, CT
# Huberta Beeson appeared in 1 cities across the dataset. For instance: New York, NY
# Ina Gaskill appeared in 1 cities across the dataset. For instance: Lansing, MI
# Iola Goodman appeared in 1 cities across the dataset. For instance: Chicago, IL
# Irene Dunn appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Irvin Mazzie appeared in 2 cities across the dataset. For instance: Richmond, IN; Sandusky, OH
# Ivey "Caldonia" Anderson appeared in 1 cities across the dataset. For instance: Chicago, IL
# J. John Howard appeared in 1 cities across the dataset. For instance: Albany, NY
# J. Sellers appeared in 0 cities across the dataset. For instance:
# Jabby Caruso appeared in 1 cities across the dataset. For instance: New York, NY
# Jack Calahan appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Jack Carr appeared in 1 cities across the dataset. For instance: Detroit, MI
# Jack Craig appeared in 1 cities across the dataset. For instance: Detroit, MI
# Jack Hughes appeared in 1 cities across the dataset. For instance: Miami, FL
# Jack Jewell appeared in 0 cities across the dataset. For instance:
# Jack King appeared in 1 cities across the dataset. For instance: Detroit, MI
# Jack Leystan appeared in 2 cities across the dataset. For instance: Russells Point, OH; Zanesville, OH
# Jack Mason appeared in 7 cities across the dataset. For instance: Albany, NY; Baltimore, MD; Glens Falls, NY
# Jack Polle appeared in 1 cities across the dataset. For instance: New York, NY
# Jack Steiner appeared in 1 cities across the dataset. For instance: Detroit, MI
# Jackie Adams appeared in 8 cities across the dataset. For instance: Albany, NY; Atlantic City, NJ; Baltimore, MD
# Jackie Bennett appeared in 1 cities across the dataset. For instance: Chicago, IL
# Jackie Collier appeared in 0 cities across the dataset. For instance:
# Jackie Dayton appeared in 2 cities across the dataset. For instance: Minneapolis, MN; Oklahoma City, OK
# Jackie Giggles appeared in 4 cities across the dataset. For instance: Albany, NY; Asbury Park, NJ; Columbus, OH
# Jackie Gordon appeared in 1 cities across the dataset. For instance: Elkhart Lake, WI
# Jackie Hughes appeared in 1 cities across the dataset. For instance: New York, NY
# Jackie Jackson appeared in 1 cities across the dataset. For instance: Miami, FL
# Jackie King appeared in 1 cities across the dataset. For instance: New York, NY
# Jackie Lane appeared in 10 cities across the dataset. For instance: Benton Harbor, MI; Binghamton, NY; Jamestown, NY
# Jackie Law appeared in 2 cities across the dataset. For instance: Atlantic City, NJ; New York, NY
# Jackie Lee appeared in 3 cities across the dataset. For instance: Asbury Park, NJ; Hartford, CT; New York, NY
# Jackie Lopez appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Jackie Lorraine appeared in 2 cities across the dataset. For instance: Albany, NY; New York, NY
# Jackie Lynch appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Jackie Maye appeared in 14 cities across the dataset. For instance: Baltimore, MD; Boston, MA; Cincinnati, OH
# Jackie Phillips appeared in 2 cities across the dataset. For instance: Fairbanks, AK; San Francisco, CA
# Jackie Sawyer appeared in 1 cities across the dataset. For instance: Detroit, MI
# Jackie Small appeared in 1 cities across the dataset. For instance: New York, NY
# Jackie Starr appeared in 6 cities across the dataset. For instance: Cleveland, OH; Denver, CO; Detroit, MI
# Jackie Thomas appeared in 3 cities across the dataset. For instance: Asbury Park, NJ; Hazleton, PA; New York, NY
# Jackie Woods appeared in 2 cities across the dataset. For instance: Houston, TX; New Orleans, LA
# Jacquette La Marr appeared in 10 cities across the dataset. For instance: Benton Harbor, MI; Binghamton, NY; Jamestown, NY
# Jakie Polee appeared in 1 cities across the dataset. For instance: Freeport, NY
# Jamaica James appeared in 1 cities across the dataset. For instance: Detroit, MI
# James Carberry appeared in 0 cities across the dataset. For instance:
# James Casalino appeared in 1 cities across the dataset. For instance: Wappingers Falls, NY
# James Costa appeared in 1 cities across the dataset. For instance: Albany, NY
# James E. Myers appeared in 1 cities across the dataset. For instance: Wappingers Falls, NY
# James Ernest Allen appeared in 1 cities across the dataset. For instance: Baltimore, MD
# James Lyons appeared in 2 cities across the dataset. For instance: Albany, NY; New York, NY
# James Riley appeared in 2 cities across the dataset. For instance: Baltimore, MD; Chicago, IL
# James Tai appeared in 1 cities across the dataset. For instance: New York, NY
# ...
# Unnamed performer at La Villa 8 appeared in 1 cities across the dataset. For instance: Syracuse, NY
# Unnamed performer at Palace Theatre appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer at Palais Royal 1 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 10 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 11 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 12 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 13 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 14 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 2 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 3 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 4 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 5 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 6 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 7 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 8 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Palais Royal 9 appeared in 1 cities across the dataset. For instance: Lansing, MI
# Unnamed performer at Plaza Cafe 1 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 2 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 3 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 4 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 5 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 6 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 7 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at Plaza Cafe 8 appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Unnamed performer at President Cafe 1 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 2 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 3 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 4 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 5 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 6 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 7 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at President Cafe 8 appeared in 1 cities across the dataset. For instance: St. Louis, MO
# Unnamed performer at Rockland Palace appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer at The Broadway 1 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 10 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 11 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 2 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 3 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 4 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 5 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 6 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 7 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 8 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Broadway 9 appeared in 1 cities across the dataset. For instance: Jamestown, NY
# Unnamed performer at The Jefferson Theatre appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer at The Paddock 1 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 10 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 11 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 12 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 13 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 14 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 2 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 3 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 4 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 5 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 6 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 7 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 8 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Paddock 9 appeared in 1 cities across the dataset. For instance: Louisville, KY
# Unnamed performer at The Stables 1 appeared in 1 cities across the dataset. For instance: Minneapolis, MN
# Unnamed performer at The Stables 2 appeared in 1 cities across the dataset. For instance: Minneapolis, MN
# Unnamed performer at The Stables 3 appeared in 1 cities across the dataset. For instance: Minneapolis, MN
# Unnamed performer at The Stables 4 appeared in 1 cities across the dataset. For instance: Minneapolis, MN
# Unnamed performer at Valle's Inn 1 appeared in 1 cities across the dataset. For instance: Portland, ME
# Unnamed performer at Valle's Inn 2 appeared in 1 cities across the dataset. For instance: Portland, ME
# Unnamed performer at Valle's Inn 3 appeared in 1 cities across the dataset. For instance: Portland, ME
# Unnamed performer at Valle's Inn 4 appeared in 1 cities across the dataset. For instance: Portland, ME
# Unnamed performer at Valle's Inn 5 appeared in 1 cities across the dataset. For instance: Portland, ME
# Unnamed performer at Wagon Wheel 1 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 10 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 11 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 12 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 13 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 14 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 2 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 3 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 4 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 5 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 6 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 7 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 8 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Wagon Wheel 9 appeared in 1 cities across the dataset. For instance: Nashville, TN
# Unnamed performer at Willis Theatre appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer at Wonder Bar 1 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at Wonder Bar 2 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at Wonder Bar 3 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at Wonder Bar 4 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at Wonder Bar 5 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at Wonder Bar 6 appeared in 1 cities across the dataset. For instance: New Orleans, LA
# Unnamed performer at the Olympia Theatre appeared in 0 cities across the dataset. For instance:
# Unnamed performer at the Regal Theatre appeared in 1 cities across the dataset. For instance: Chicago, IL
# Unnamed performer from Bob Copfer Four appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer from Earle appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Unnamed performer from The Mimic Men 2 appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer from Winslow Four appeared in 1 cities across the dataset. For instance: New York, NY
# Unnamed performer hissed off stage appeared in 0 cities across the dataset. For instance:
# Unnamed performer in The Seven Collegians appeared in 1 cities across the dataset. For instance: Rochester, NY
# Unnamed tall, black performer appeared in 1 cities across the dataset. For instance: New York, NY
# Val Rai appeared in 2 cities across the dataset. For instance: Reno, NV; Seattle, WA
# Val Turek appeared in 2 cities across the dataset. For instance: Akron, OH; Massillon, OH
# Val Varr appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Valda Gray appeared in 1 cities across the dataset. For instance: Chicago, IL
# Vera Mazzie appeared in 1 cities across the dataset. For instance: Benton Harbor, MI
# Vera Walters appeared in 1 cities across the dataset. For instance: Freeport, NY
# Verida Pearson appeared in 1 cities across the dataset. For instance: New York, NY
# Verne Valdez appeared in 13 cities across the dataset. For instance: Baltimore, MD; Cleveland, OH; Columbus, OH
# Vernon Fountain appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Vernon Hoff appeared in 13 cities across the dataset. For instance: Akron, OH; Chicago, IL; Cincinnati, OH
# Vicki appeared in 1 cities across the dataset. For instance: Chicago, IL
# Vincent McFarland appeared in 1 cities across the dataset. For instance: New York City, NY
# Vincent Reid appeared in 2 cities across the dataset. For instance: New York, NY; Philadelphia, PA
# Viola Layne appeared in 1 cities across the dataset. For instance: New York, NY
# Violet Ceravola appeared in 1 cities across the dataset. For instance: Miami, FL
# Violet Clements appeared in 1 cities across the dataset. For instance: Miami, FL
# Wallace Reed appeared in 1 cities across the dataset. For instance: Davenport, IA
# Wallie Groff appeared in 1 cities across the dataset. For instance: Versailles, MO
# Wally Brennan appeared in 2 cities across the dataset. For instance: Albany, NY; Saratoga Springs, NY
# Wally Thompson appeared in 1 cities across the dataset. For instance: Miami, FL
# Walter Davis appeared in 1 cities across the dataset. For instance: Lima, OH
# Walter Hart appeared in 1 cities across the dataset. For instance: San Francisco, CA
# Walter McDonald appeared in 1 cities across the dataset. For instance: Miami, FL
# Walter Morgan appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# Walter Munde appeared in 1 cities across the dataset. For instance: New York, NY
# Walter Thomas appeared in 1 cities across the dataset. For instance: Pittsburgh, PA
# Wanda Bean appeared in 1 cities across the dataset. For instance: Chicago, IL
# Weldon Short appeared in 1 cities across the dataset. For instance: El Paso, TX
# Wesley Davis appeared in 6 cities across the dataset. For instance: Berwyn, IL; Chicago, IL; Cincinnati, OH
# Whitey Harris appeared in 0 cities across the dataset. For instance:
# Wilkie Mason appeared in 3 cities across the dataset. For instance: Cincinnati, OH; Detroit, MI; Minneapolis, MN
# William Green appeared in 0 cities across the dataset. For instance:
# William Harris appeared in 1 cities across the dataset. For instance: New York, NY
# William Johnson appeared in 1 cities across the dataset. For instance: Los Angeles, CA
# William Lee Becker appeared in 1 cities across the dataset. For instance: Wappingers Falls, NY
# Willie Duices appeared in 0 cities across the dataset. For instance:
# Woody Wilson appeared in 1 cities across the dataset. For instance: Cincinnati, OH
# Yonder Thompson appeared in 0 cities across the dataset. For instance:
# Yvonne — appeared in 1 cities across the dataset. For instance: Detroit, MI
# Zalman appeared in 0 cities across the dataset. For instance:
# Zorina La Cross appeared in 1 cities across the dataset. For instance: Lima, OH
# [Harold Shinn] appeared in 1 cities across the dataset. For instance: New Orleans, LA
# — Alexandria appeared in 0 cities across the dataset. For instance:
# — Allworth appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# — Brennan appeared in 1 cities across the dataset. For instance: New York, NY
# — Burns appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# — Diana appeared in 1 cities across the dataset. For instance: Kansas City, MO
# — Diaz appeared in 1 cities across the dataset. For instance: Kansas City, MO
# — Dion appeared in 2 cities across the dataset. For instance: Akron, OH; Detroit, MI
# — Dunn appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# — Enesco appeared in 2 cities across the dataset. For instance: Chicago, IL; Miami, FL
# — Gresham appeared in 1 cities across the dataset. For instance: Baltimore, MD
# — Kay appeared in 1 cities across the dataset. For instance: Kansas City, MO
# — King appeared in 1 cities across the dataset. For instance: New York, NY
# — Knox appeared in 1 cities across the dataset. For instance: Baltimore, MD
# — La Mar appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# — Lacy appeared in 1 cities across the dataset. For instance: Grand Rapids, MI
# — Leslie appeared in 1 cities across the dataset. For instance: Baltimore, MD
# — Lewis appeared in 1 cities across the dataset. For instance: Chicago, IL
# — Mack appeared in 1 cities across the dataset. For instance: Baltimore, MD
# — Marion appeared in 2 cities across the dataset. For instance: Akron, OH; Detroit, MI
# — Marshall appeared in 1 cities across the dataset. For instance: Boston, MA
# — Mitchell appeared in 1 cities across the dataset. For instance: Baltimore, MD
# — Morton appeared in 1 cities across the dataset. For instance: Philadelphia, PA
# — Ryck appeared in 1 cities across the dataset. For instance: Kansas City, MO
# — Satch appeared in 1 cities across the dataset. For instance: New York, NY
# — Satchell appeared in 1 cities across the dataset. For instance: New York, NY
# — Williams appeared in 1 cities across the dataset. For instance: Chicago, IL
# — Yvonne appeared in 1 cities across the dataset. For instance: Philadelphia, PA
